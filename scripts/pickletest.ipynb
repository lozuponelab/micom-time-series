# %%
import pandas as pd
import pickle


# Load a pickle file
pickletest_fp = '../data/pickled_models/pickled_M01_agora201_gurobi_20260112/1208476800.pickle'

with open(pickletest_fp, 'rb') as f:
    pickletest = pickle.load(f)

# %%
print(pickletest)
# Out:
# 1208476800
